# %%
import pandas as pd
mpg = pd.read_csv('C:/Users/USER-PC/anaconda3/WorkSpace/Doit_Python/Data/mpg.csv')

# %%
import seaborn as sns
sns.scatterplot(data = mpg, x = 'displ', y = 'hwy')
# Out:
# <AxesSubplot:xlabel='displ', ylabel='hwy'>

# %%
sns.scatterplot(data = mpg, x = 'displ', y = 'hwy').set(xlim = (3,6))
# Out:
# [(3.0, 6.0)]

# %%
sns.scatterplot(data = mpg, x = 'displ', y = 'hwy').set(xlim = (3,6), ylim = (10, 30))
# Out:
# [(3.0, 6.0), (10.0, 30.0)]

# %%
sns.scatterplot(data = mpg, x = 'displ', y = 'hwy', hue = 'drv')
# Out:
# <AxesSubplot:xlabel='displ', ylabel='hwy'>

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.dpi' : '150'})
plt.rcParams.update({'figure.figsize' : [8, 6]})
plt.rcParams.update({'font.size' : '15'})
plt.rcParams.update({'font.family': 'Malgun Gothic'})

# %%
sns.scatterplot(data = mpg, x = 'cty', y = 'hwy')
# Out:
# <AxesSubplot:xlabel='cty', ylabel='hwy'>

# %%
midwest = pd.read_csv('C:/Users/USER-PC/anaconda3/WorkSpace/Doit_Python/Data/midwest.csv')
sns.scatterplot(data = midwest, x = 'poptotal', y = 'popasian').set(xlim = (0, 500000), ylim = (0, 10000))
# Out:
# [(0.0, 500000.0), (0.0, 10000.0)]

# %%
df_mpg = mpg.groupby('drv', as_index = False).agg(mean_hwy = ('hwy', 'mean'))
df_mpg
# Out:
#   drv   mean_hwy
# 0   4  19.174757
# 1   f  28.160377
# 2   r  21.000000

# %%
sns.barplot(data = df_mpg, x = 'drv', y = 'mean_hwy')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='mean_hwy'>

# %%
df_mpg = df_mpg.sort_values('mean_hwy', ascending = False)

sns.barplot(data = df_mpg, x = 'drv', y = 'mean_hwy')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='mean_hwy'>

# %%
df_mpg = mpg.groupby('drv', as_index = False).agg(n = ('drv', 'count'))
df_mpg
# Out:
#   drv    n
# 0   4  103
# 1   f  106
# 2   r   25

# %%
sns.barplot(data = df_mpg, x = 'drv', y = 'n')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='n'>

# %%
sns.countplot(data = mpg, x = 'drv')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='count'>

# %%
mpg['drv'].unique()
# Out:
# array(['f', '4', 'r'], dtype=object)

# %%
sns.countplot(data = mpg, x = 'drv', order = ['4', 'f', 'r'])
# Out:
# <AxesSubplot:xlabel='drv', ylabel='count'>

# %%
sns.countplot(data = mpg, x = 'drv', order = mpg['drv'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='drv', ylabel='count'>

# %%
mpg_suv = mpg.query('category == "suv"')
df_mpg = mpg_suv.groupby('manufacturer', as_index = False).agg(mean_cty = ('cty', 'mean'))
df_mpg = df_mpg.sort_values('mean_cty', ascending = False).head()
sns.barplot(data = df_mpg, x = 'manufacturer', y = 'mean_cty')
# Out:
# <AxesSubplot:xlabel='manufacturer', ylabel='mean_cty'>

# %%
mpg = pd.read_csv('C:/Users/USER-PC/anaconda3/WorkSpace/Doit_Python/Data/mpg.csv')
mpg = mpg.groupby('category', as_index = False).agg(n = ('category', 'count'))
mpg = mpg.sort_values('n', ascending = False)

sns.barplot(data = mpg, x = 'category', y = 'n')
# Out:
# <AxesSubplot:xlabel='category', ylabel='n'>

# %%
economics = pd.read_csv('C:/Users/USER-PC/anaconda3/WorkSpace/Doit_Python/Data/economics.csv')
economics
# Out:
#            date      pce         pop  psavert  uempmed  unemploy
# 0    1967-07-01    506.7  198712.000     12.6      4.5      2944
# 1    1967-08-01    509.8  198911.000     12.6      4.7      2945
# 2    1967-09-01    515.6  199113.000     11.9      4.6      2958
# 3    1967-10-01    512.2  199311.000     12.9      4.9      3143
# 4    1967-11-01    517.4  199498.000     12.8      4.7      3066
# ..          ...      ...         ...      ...      ...       ...
# 569  2014-12-01  12062.0  319746.157      7.6     12.9      8717
# 570  2015-01-01  12046.0  319928.646      7.7     13.2      8903
# 571  2015-02-01  12082.4  320074.511      7.9     12.9      8610
# 572  2015-03-01  12158.3  320230.786      7.4     12.0      8504
# 573  2015-04-01  12193.8  320402.295      7.6     11.5      8526
#
# [574 rows x 6 columns]

# %%
sns.lineplot(data = economics, x = 'date', y = 'unemploy')
# Out:
# <AxesSubplot:xlabel='date', ylabel='unemploy'>

# %%
economics['date2'] = pd.to_datetime(economics['date'])

economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      574 non-null    object
#  1   pce       574 non-null    float64
#  2   pop       574 non-null    float64
#  3   psavert   574 non-null    float64
#  4   uempmed   574 non-null    float64
#  5   unemploy  574 non-null    int64
#  6   date2     574 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 31.5+ KB

# %%
economics[['date', 'date2']]
# Out:
#            date      date2
# 0    1967-07-01 1967-07-01
# 1    1967-08-01 1967-08-01
# 2    1967-09-01 1967-09-01
# 3    1967-10-01 1967-10-01
# 4    1967-11-01 1967-11-01
# ..          ...        ...
# 569  2014-12-01 2014-12-01
# 570  2015-01-01 2015-01-01
# 571  2015-02-01 2015-02-01
# 572  2015-03-01 2015-03-01
# 573  2015-04-01 2015-04-01
#
# [574 rows x 2 columns]

# %%
print(economics['date2'].dt.year)
print(economics['date2'].dt.month)
print(economics['date2'].dt.day)
# Out:
# 0      1967
# 1      1967
# 2      1967
# 3      1967
# 4      1967
#        ...
# 569    2014
# 570    2015
# 571    2015
# 572    2015
# 573    2015
# Name: date2, Length: 574, dtype: int64
# 0       7
# 1       8
# 2       9
# 3      10
# 4      11
#        ..
# 569    12
# 570     1
# 571     2
# 572     3
# 573     4
# Name: date2, Length: 574, dtype: int64
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 569    1
# 570    1
# 571    1
# 572    1
# 573    1
# Name: date2, Length: 574, dtype: int64

# %%
economics['year'] = economics['date2'].dt.year
economics.head()
# Out:
#          date    pce       pop  psavert  uempmed  unemploy      date2  year
# 0  1967-07-01  506.7  198712.0     12.6      4.5      2944 1967-07-01  1967
# 1  1967-08-01  509.8  198911.0     12.6      4.7      2945 1967-08-01  1967
# 2  1967-09-01  515.6  199113.0     11.9      4.6      2958 1967-09-01  1967
# 3  1967-10-01  512.2  199311.0     12.9      4.9      3143 1967-10-01  1967
# 4  1967-11-01  517.4  199498.0     12.8      4.7      3066 1967-11-01  1967

# %%
sns.lineplot(data = economics, x = 'year', y = 'unemploy')
# Out:
# <AxesSubplot:xlabel='year', ylabel='unemploy'>

# %%
sns.lineplot(data = economics, x = 'year', y = 'unemploy', ci = None)
# Out:
# <AxesSubplot:xlabel='year', ylabel='unemploy'>

# %%
economics = pd.read_csv('C:/Users/USER-PC/anaconda3/WorkSpace/Doit_Python/Data/economics.csv')
economics['date2'] = pd.to_datetime(economics['date'])
economics['year'] = economics['date2'].dt.year
sns.lineplot(data = economics, x = 'year', y = 'psavert')
# Out:
# <AxesSubplot:xlabel='year', ylabel='psavert'>

# %%
economics = pd.read_csv('C:/Users/USER-PC/anaconda3/WorkSpace/Doit_Python/Data/economics.csv')
economics['date2'] = pd.to_datetime(economics['date'])
economics['year'] = economics['date2'].dt.year
economics['month'] = economics['date2'].dt.month
economics = economics.query('year == 2014')
sns.lineplot(data = economics, x = 'month', y = 'psavert')
# Out:
# <AxesSubplot:xlabel='month', ylabel='psavert'>

# %%
mpg = pd.read_csv('C:/Users/USER-PC/anaconda3/WorkSpace/Doit_Python/Data/mpg.csv')

sns.boxplot(data = mpg, x = 'drv', y = 'hwy')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='hwy'>

# %%
mpg = mpg.query('category == "compact" | category == "subcompact" | category == "suv"')
sns.boxplot(data = mpg, x = 'category', y = 'cty')
# Out:
# <AxesSubplot:xlabel='category', ylabel='cty'>
